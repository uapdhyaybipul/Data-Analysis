# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('people.csv')
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
df.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df_corr=df.corr(numeric_only=True)
df_corr
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.105021         -0.142970
# lastEvaluation                  0.105021        1.000000          0.349333
# numberOfProjects               -0.142970        0.349333          1.000000
# avgMonthlyHours                -0.020048        0.339742          0.417211
# timeSpent.company              -0.100866        0.131591          0.196786
# workAccident                    0.058697       -0.007104         -0.004741
# left                           -0.388375        0.006567          0.023787
# promotionInLast5years           0.025605       -0.008684         -0.006064
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.020048          -0.100866      0.058697
# lastEvaluation                0.339742           0.131591     -0.007104
# numberOfProjects              0.417211           0.196786     -0.004741
# ...

# %%
df['left']

##stayed in company
##left company
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    0
# 14996    0
# 14997    0
# 14998    0
# Name: left, Length: 14999, dtype: int64

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Project

# %%
sns.countplot(df,x='numberOfProjects',hue='left'	)
plt.show()

# %% [markdown]
# **employee having two projects and more than 6 projects are likely to leave the company**

# %% [markdown]
# ### Promotion In Last 5years

# %%
sns.countplot(df,x='promotionInLast5years',hue='left')
# Out:
# <Axes: xlabel='promotionInLast5years', ylabel='count'>

# %% [markdown]
# **quite peoples are leaving ,not having hike in their salary**

# %% [markdown]
# ### satisfactoryLevel vs avgMonthlyHours

# %%
sns.lineplot(df,x='satisfactoryLevel',y='avgMonthlyHours',hue='left')
# Out:
# <Axes: xlabel='satisfactoryLevel', ylabel='avgMonthlyHours'>

# %% [markdown]
# #### As the ''satisfactory level'' column and ''left'' column has the negative correation
# **employees who are working more than 230hrs and less than 175hrs avg of monthly are leaving the company**
# **Can be improved by alloting 220 hrs avg of work monthly to all the employee to enhance the satisfactory level**
