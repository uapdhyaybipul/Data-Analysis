# %% [markdown]
# # API---Application Progamming Interface

# %% [markdown]
# ---is a way for two or more homogeneous,heteregenous computer programs or components to communicate with each other. It is a type of software interface, offering a service to other pieces of software.

# %% [markdown]
# ## Web Scrapping

# %% [markdown]
# ![image.png](attachment:af17ae5c-d5e3-4af7-8bc1-26a8f80f210f.png)

# %% [markdown]
# **Large amounts of data from a website to train a Machine Learning algorithm? In such a situation, copying and pasting will not work! And that’s when you’ll need to use Web Scraping. Web scraping is an automatic method to obtain large amounts of data from websites. Most of this data is unstructured data in an HTML format which is then converted into structured data in a spreadsheet or a database so that it can be used in various applications.
# when a web scraper needs to scrape a site, first the URLs are provided. Then it loads all the HTML code for those sites and a more advanced scraper might even extract all the CSS and Javascript elements as well. Then the scraper obtains the required data from this HTML code and outputs this data in the format specified by the user. Mostly, this is in the form of an Excel spreadsheet or a CSV file, but the data can also be saved in other formats, such as a JSON file.**   `Source~geeks for geeks`

# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()
driver.get('https://www.flipkart.com/')
driver.find_element(By.XPATH,'//*[@id="container"]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[2]/div[1]/div/div[1]/div/div/div/div/div[1]/a[2]').click()
get_url = driver.current_url
print("The current url is:"+str(get_url))
driver.quit()
# Out:
# The current url is:https://www.flipkart.com/mobile-phones-store?fm=neo%2Fmerchandising&iid=M_93009204-84cd-4ec3-997b-029d107350b8_1_372UD5BXDFYS_MC.ZRQ4DKH28K8J&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Mobiles_ZRQ4DKH28K8J&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L0_view-all&cid=ZRQ4DKH28K8J

# %%
link_text=requests.get(get_url).text
print(link_text)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" si
# ...

# %%
pip install lxml

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(link_text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim2.flixcart.com" rel="preconnect"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css" rel="stylesheet"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>\n  <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>\n  <link href="/apple-touch-icon-57x57.png" rel="apple-touc
# ...

# %%
mydivs = soup.findAll("div", {"class":"_1AtVbE col-12-12"})
print(mydivs)
# Out:
# [<div class="_1AtVbE col-12-12" style="padding:6px 0px 6px 0px"><div class="_3WcRHs"><div class="_3ywSr_" style="padding-top:25.18%"><div class="_1bEAQy _312yBx" style="padding-top:25.18%"><img alt="a" class="_2OHU_q"/><img alt="a" class="kJjFO0 _3DIhEh" src="https://rukminim2.flixcart.com/fk-p-flap/100/100/image/71b86992256b69d4.jpg?q=50"/></div></div></div></div>, <div class="_1AtVbE col-12-12" style="padding:6px 0px 6px 0px"><div class="_3WcRHs"><div class="_3ywSr_" style="padding-top:14.39%"><div class="_1bEAQy _312yBx" style="padding-top:14.39%"><img alt="v" class="_2OHU_q"/><img alt="v" class="kJjFO0 _3DIhEh" src="https://rukminim2.flixcart.com/fk-p-flap/100/100/image/35577fa6e1c9843d.jpg?q=50"/></div></div></div></div>, <div class="_1AtVbE col-12-12" style="padding:0px 0px 0px 0px"><div class="_3WcRHs"><div class="_3ywSr_" style="padding-top:8.63%"><div class="_1bEAQy _312yBx" style="padding-top:8.63%"><img alt="Sale-of-the-Day" class="_2OHU_q"/><img alt="Sale-of-the-Day" clas
# ...

# %%
lst=[]
all_phone=soup.find_all('a')
for phone in all_phone:
    lst.append(phone.get('href'))
lst
# Out:
# ['/',
#  '/plus',
#  '/account/login?ret=/mobile-phones-store%3Ffm%3Dneo%252Fmerchandising%26iid%3DM_93009204-84cd-4ec3-997b-029d107350b8_1_372UD5BXDFYS_MC.ZRQ4DKH28K8J%26otracker%3Dhp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Mobiles_ZRQ4DKH28K8J%26otracker1%3Dhp_rich_navigation_PINNED_neo%252Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L0_view-all%26cid%3DZRQ4DKH28K8J',
#  'https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect',
#  '/viewcart?exploreMode=true&preference=FLIPKART',
#  '/apple-iphone-15-black-128-gb/p/itm6ac6485515ae4',
#  '/apple-iphone-15-plus-blue-128-gb/p/itm4022c14383050',
#  '/apple-iphone-15-pro-blue-titanium-128-gb/p/itmcba9124f132a8',
#  '/apple-iphone-15-pro-max-blue-titanium-256-gb/p/itm4a0093df4a3d7',
#  '/vivo-x100-asteroid-black-256-gb/p/itm60fe0113c39cb',
#  '/oppo-reno-11-5g-wave-green-128-gb/p/itm12beb0da508b1',
#  '/oppo-reno-11-pro-5g-pearl-white-256-gb/p/itm18c5d66bdfaa4',
# ...

# %%
url_lst=[]
for i in lst[6:18]:
    url_lst.append(i)
print(url_lst)
# Out:
# ['/apple-iphone-15-plus-blue-128-gb/p/itm4022c14383050', '/apple-iphone-15-pro-blue-titanium-128-gb/p/itmcba9124f132a8', '/apple-iphone-15-pro-max-blue-titanium-256-gb/p/itm4a0093df4a3d7', '/vivo-x100-asteroid-black-256-gb/p/itm60fe0113c39cb', '/oppo-reno-11-5g-wave-green-128-gb/p/itm12beb0da508b1', '/oppo-reno-11-pro-5g-pearl-white-256-gb/p/itm18c5d66bdfaa4', '/infinix-smart-8-rainbow-blue-64-gb/p/itmb5696a34ad441', '/google-pixel-7a-sea-128-gb/p/itmb4d7b100b1a4d', '/motorola-edge-40-jet-black-256-gb/p/itmbe5b18bf1f229', '/poco-c55-cool-blue-64-gb/p/itm166c52f5d5dc0', '/samsung-galaxy-s24-5g-amber-yellow-256-gb/p/itmebc700bb8d159', '/mobiles-accessories/pr?sid=tyy&otracker=categorytree']

# %%
for i in lst[32:52]:
    url_lst.append(i)
print(url_lst)
# Out:
# ['/apple-iphone-15-plus-blue-128-gb/p/itm4022c14383050', '/apple-iphone-15-pro-blue-titanium-128-gb/p/itmcba9124f132a8', '/apple-iphone-15-pro-max-blue-titanium-256-gb/p/itm4a0093df4a3d7', '/vivo-x100-asteroid-black-256-gb/p/itm60fe0113c39cb', '/oppo-reno-11-5g-wave-green-128-gb/p/itm12beb0da508b1', '/oppo-reno-11-pro-5g-pearl-white-256-gb/p/itm18c5d66bdfaa4', '/infinix-smart-8-rainbow-blue-64-gb/p/itmb5696a34ad441', '/google-pixel-7a-sea-128-gb/p/itmb4d7b100b1a4d', '/motorola-edge-40-jet-black-256-gb/p/itmbe5b18bf1f229', '/poco-c55-cool-blue-64-gb/p/itm166c52f5d5dc0', '/samsung-galaxy-s24-5g-amber-yellow-256-gb/p/itmebc700bb8d159', '/mobiles-accessories/pr?sid=tyy&otracker=categorytree', '/realme-11x-5g-purple-dawn-128-gb/p/itm07be1a2ff1a1b?pid=MOBGS2WFBDQBD2B4&lid=LSTMOBGS2WFBDQBD2B41C9ZEH&marketplace=FLIPKART', '/motorola-g34-5g-ocean-green-128-gb/p/itm6b1a33b9d9191?pid=MOBGUFK4TZ2CJYHJ&lid=LSTMOBGUFK4TZ2CJYHJPBUF6M&marketplace=FLIPKART', '/poco-c51-locked-airtel-prepaid-royal-blu
# ...

# %%
url_lst
# Out:
# ['/apple-iphone-15-plus-blue-128-gb/p/itm4022c14383050',
#  '/apple-iphone-15-pro-blue-titanium-128-gb/p/itmcba9124f132a8',
#  '/apple-iphone-15-pro-max-blue-titanium-256-gb/p/itm4a0093df4a3d7',
#  '/vivo-x100-asteroid-black-256-gb/p/itm60fe0113c39cb',
#  '/oppo-reno-11-5g-wave-green-128-gb/p/itm12beb0da508b1',
#  '/oppo-reno-11-pro-5g-pearl-white-256-gb/p/itm18c5d66bdfaa4',
#  '/infinix-smart-8-rainbow-blue-64-gb/p/itmb5696a34ad441',
#  '/google-pixel-7a-sea-128-gb/p/itmb4d7b100b1a4d',
#  '/motorola-edge-40-jet-black-256-gb/p/itmbe5b18bf1f229',
#  '/poco-c55-cool-blue-64-gb/p/itm166c52f5d5dc0',
#  '/samsung-galaxy-s24-5g-amber-yellow-256-gb/p/itmebc700bb8d159',
#  '/mobiles-accessories/pr?sid=tyy&otracker=categorytree',
#  '/realme-11x-5g-purple-dawn-128-gb/p/itm07be1a2ff1a1b?pid=MOBGS2WFBDQBD2B4&lid=LSTMOBGS2WFBDQBD2B41C9ZEH&marketplace=FLIPKART',
#  '/motorola-g34-5g-ocean-green-128-gb/p/itm6b1a33b9d9191?pid=MOBGUFK4TZ2CJYHJ&lid=LSTMOBGUFK4TZ2CJYHJPBUF6M&marketplace=FLIPKART',
# ...

# %%
len(url_lst)
# Out:
# 32

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
mobile_links=[]
for i in url_lst[0:33]:
    mobile_links.append('https://www.flipkart.com'+i)
mobile_links.pop(11)
print(mobile_links)
# Out:
# ['https://www.flipkart.com/apple-iphone-15-plus-blue-128-gb/p/itm4022c14383050', 'https://www.flipkart.com/apple-iphone-15-pro-blue-titanium-128-gb/p/itmcba9124f132a8', 'https://www.flipkart.com/apple-iphone-15-pro-max-blue-titanium-256-gb/p/itm4a0093df4a3d7', 'https://www.flipkart.com/vivo-x100-asteroid-black-256-gb/p/itm60fe0113c39cb', 'https://www.flipkart.com/oppo-reno-11-5g-wave-green-128-gb/p/itm12beb0da508b1', 'https://www.flipkart.com/oppo-reno-11-pro-5g-pearl-white-256-gb/p/itm18c5d66bdfaa4', 'https://www.flipkart.com/infinix-smart-8-rainbow-blue-64-gb/p/itmb5696a34ad441', 'https://www.flipkart.com/google-pixel-7a-sea-128-gb/p/itmb4d7b100b1a4d', 'https://www.flipkart.com/motorola-edge-40-jet-black-256-gb/p/itmbe5b18bf1f229', 'https://www.flipkart.com/poco-c55-cool-blue-64-gb/p/itm166c52f5d5dc0', 'https://www.flipkart.com/samsung-galaxy-s24-5g-amber-yellow-256-gb/p/itmebc700bb8d159', 'https://www.flipkart.com/realme-11x-5g-purple-dawn-128-gb/p/itm07be1a2ff1a1b?pid=MOBGS2WFBDQ
# ...

# %%
len(mobile_links)
# Out:
# 31

# %%
for i in mobile_links:
    print(i)
# Out:
# https://www.flipkart.com/apple-iphone-15-plus-blue-128-gb/p/itm4022c14383050
# https://www.flipkart.com/apple-iphone-15-pro-blue-titanium-128-gb/p/itmcba9124f132a8
# https://www.flipkart.com/apple-iphone-15-pro-max-blue-titanium-256-gb/p/itm4a0093df4a3d7
# https://www.flipkart.com/vivo-x100-asteroid-black-256-gb/p/itm60fe0113c39cb
# https://www.flipkart.com/oppo-reno-11-5g-wave-green-128-gb/p/itm12beb0da508b1
# https://www.flipkart.com/oppo-reno-11-pro-5g-pearl-white-256-gb/p/itm18c5d66bdfaa4
# https://www.flipkart.com/infinix-smart-8-rainbow-blue-64-gb/p/itmb5696a34ad441
# https://www.flipkart.com/google-pixel-7a-sea-128-gb/p/itmb4d7b100b1a4d
# https://www.flipkart.com/motorola-edge-40-jet-black-256-gb/p/itmbe5b18bf1f229
# https://www.flipkart.com/poco-c55-cool-blue-64-gb/p/itm166c52f5d5dc0
# https://www.flipkart.com/samsung-galaxy-s24-5g-amber-yellow-256-gb/p/itmebc700bb8d159
# https://www.flipkart.com/mobiles-accessories/pr?sid=tyy&otracker=categorytree
# ...

# %%
from selenium.common.exceptions import NoSuchElementException
mobiles=[]
for i in mobile_links[:]:
    driver=webdriver.Chrome()
    driver.get(i)
    get=driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[2]/div/div[1]/h1/span').text
    mobiles.append(get)

# %%
import pandas as pd

# %%
df=pd.DataFrame(mobiles,columns=['Name'])
df
index = pd.Index(range(1,32))
df = df.set_index(index)
df
# Out:
#                                                  Name
# 1                 Apple iPhone 15 Plus (Blue, 128 GB)
# 2         Apple iPhone 15 Pro (Blue Titanium, 128 GB)
# 3     Apple iPhone 15 Pro Max (Blue Titanium, 256 GB)
# 4      vivo X100 (Stargaze Blue, 256 GB)  (12 GB RAM)
# 5     OPPO Reno11 5G (Wave Green, 128 GB)  (8 GB RAM)
# 6   OPPO Reno11 Pro 5G (Pearl White, 256 GB)  (12 ...
# 7   Infinix SMART 8 (Rainbow Blue, 64 GB)  (4 GB RAM)
# 8           Google Pixel 7a (Sea, 128 GB)  (8 GB RAM)
# 9   Motorola Edge 40 (Eclipse Black, 256 GB)  (8 G...
# 10            POCO C55 (Cool Blue, 64 GB)  (4 GB RAM)
# 11  SAMSUNG Galaxy S24 5G (Amber Yellow, 256 GB)  ...
# 12    realme 11x 5G (Purple Dawn, 128 GB)  (6 GB RAM)
# 13  Motorola G34 5G (Ocean Green, 128 GB)  (8 GB RAM)
# 14  POCO C51 - Locked with Airtel Prepaid (Royal B...
# 15  realme 12 Pro+ 5G (Submarine Blue, 256 GB)  (8...
# 16     vivo T2 Pro 5G (Dune Gold, 256 GB)  (8 GB RAM)
# ...

# %%
mobiles
# Out:
# ['Apple iPhone 15 Plus (Blue, 128 GB)',
#  'Apple iPhone 15 Pro (Blue Titanium, 128 GB)',
#  'Apple iPhone 15 Pro Max (Blue Titanium, 256 GB)',
#  'vivo X100 (Stargaze Blue, 256 GB)  (12 GB RAM)',
#  'OPPO Reno11 5G (Wave Green, 128 GB)  (8 GB RAM)',
#  'OPPO Reno11 Pro 5G (Pearl White, 256 GB)  (12 GB RAM)',
#  'Infinix SMART 8 (Rainbow Blue, 64 GB)  (4 GB RAM)',
#  'Google Pixel 7a (Sea, 128 GB)  (8 GB RAM)',
#  'Motorola Edge 40 (Eclipse Black, 256 GB)  (8 GB RAM)',
#  'POCO C55 (Cool Blue, 64 GB)  (4 GB RAM)',
#  'SAMSUNG Galaxy S24 5G (Amber Yellow, 256 GB)  (8 GB RAM)',
#  'realme 11x 5G (Purple Dawn, 128 GB)  (6 GB RAM)',
#  'Motorola G34 5G (Ocean Green, 128 GB)  (8 GB RAM)',
#  'POCO C51 - Locked with Airtel Prepaid (Royal Blue, 64 GB)  (4 GB RAM)',
#  'realme 12 Pro+ 5G (Submarine Blue, 256 GB)  (8 GB RAM)',
#  'vivo T2 Pro 5G (Dune Gold, 256 GB)  (8 GB RAM)',
#  'Motorola g84 5G (Viva Magenta, 256 GB)  (12 GB RAM)',
#  'realme 11 5G (Glory Gold, 128 GB)  (8 GB RAM)',
# ...

# %%
review_count=[]
for i in mobile_links[0:32]:
    driver=webdriver.Chrome()
    driver.get(i)
    try:
        get2=driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[7]/div/div[2]/div[1]/div/div[2]/div/ul[3]/li[1]/div').text
        review_count.append(get2)
    except:
       review_count.append(np.NaN)

# %%
import numpy as np
review_count
# Out:
# ['2,148',
#  '399',
#  '292',
#  '293',
#  '1,460',
#  '655',
#  '1,317',
#  '9,211',
#  '44,719',
#  nan,
#  '160',
#  nan,
#  nan,
#  nan,
#  '285',
#  '45,500',
#  '17,422',
#  '32,540',
#  '2,23,062',
#  nan,
#  nan,
#  '32,540',
#  '71,555',
#  '55,495',
#  '40,005',
#  '45,500',
#  '906',
#  '509',
#  nan,
#  '58,034',
#  '1,03,305']

# %%
len(review_count)
# Out:
# 31

# %%
dict={'Name':mobiles,'5* ratings':review_count,'Battery':Battery_count
     }
rating_df=pd.DataFrame(dict)
rating_df
# Out:
#                                                  Name 5* ratings  \
# 0                 Apple iPhone 15 Plus (Blue, 128 GB)      2,148
# 1         Apple iPhone 15 Pro (Blue Titanium, 128 GB)        399
# 2     Apple iPhone 15 Pro Max (Blue Titanium, 256 GB)        292
# 3      vivo X100 (Stargaze Blue, 256 GB)  (12 GB RAM)        293
# 4     OPPO Reno11 5G (Wave Green, 128 GB)  (8 GB RAM)      1,460
# 5   OPPO Reno11 Pro 5G (Pearl White, 256 GB)  (12 ...        655
# 6   Infinix SMART 8 (Rainbow Blue, 64 GB)  (4 GB RAM)      1,317
# 7           Google Pixel 7a (Sea, 128 GB)  (8 GB RAM)      9,211
# 8   Motorola Edge 40 (Eclipse Black, 256 GB)  (8 G...     44,719
# 9             POCO C55 (Cool Blue, 64 GB)  (4 GB RAM)        NaN
# 10  SAMSUNG Galaxy S24 5G (Amber Yellow, 256 GB)  ...        160
# 11    realme 11x 5G (Purple Dawn, 128 GB)  (6 GB RAM)        NaN
# 12  Motorola G34 5G (Ocean Green, 128 GB)  (8 GB RAM)        NaN
# ...

# %%
Battery_count=[]
for i in mobile_links[0:32]:
    driver=webdriver.Chrome()
    driver.get(i)
    try:
        get2=driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]').text
        Battery_count.append(get2)
    except:
       Battery_count.append(np.NaN)

# %%
Battery_count
# Out:
# ['A16 Bionic Chip, 6 Core Processor Processor',
#  'A17 Pro Chip, 6 Core Processor Processor',
#  'A17 Pro Chip, 6 Core Processor Processor',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '4600 mAh Battery',
#  '5000 mAh Battery',
#  '4300 mAh Battery',
#  '4400 mAh Battery',
#  nan,
#  '4000 mAh Battery',
#  '5000 mAh Battery',
#  nan,
#  nan,
#  '5000 mAh Battery',
#  nan,
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  nan,
#  nan,
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '4600 mAh Battery',
#  '4575 mAh Battery',
#  nan,
#  nan,
#  nan,
#  '5000 mAh Battery']

# %%
rating_df.loc[9,'Battery']=rating_df.loc[30,'Battery']

# %%
rating_df.to_csv(r'D:\bipul\Python\abc\mobile.csv')

# %%
rating_df
# Out:
#                                                  Name 5* ratings  \
# 0                 Apple iPhone 15 Plus (Blue, 128 GB)      2,148
# 1         Apple iPhone 15 Pro (Blue Titanium, 128 GB)        399
# 2     Apple iPhone 15 Pro Max (Blue Titanium, 256 GB)        292
# 3      vivo X100 (Stargaze Blue, 256 GB)  (12 GB RAM)        293
# 4     OPPO Reno11 5G (Wave Green, 128 GB)  (8 GB RAM)      1,460
# 5   OPPO Reno11 Pro 5G (Pearl White, 256 GB)  (12 ...        655
# 6   Infinix SMART 8 (Rainbow Blue, 64 GB)  (4 GB RAM)      1,317
# 7           Google Pixel 7a (Sea, 128 GB)  (8 GB RAM)      9,211
# 8   Motorola Edge 40 (Eclipse Black, 256 GB)  (8 G...     44,719
# 9             POCO C55 (Cool Blue, 64 GB)  (4 GB RAM)        NaN
# 10  SAMSUNG Galaxy S24 5G (Amber Yellow, 256 GB)  ...        160
# 11    realme 11x 5G (Purple Dawn, 128 GB)  (6 GB RAM)        NaN
# 12  Motorola G34 5G (Ocean Green, 128 GB)  (8 GB RAM)        NaN
# ...

# %%
df=pd.read_csv('abc/mobile.csv')
df
# Out:
#     Unnamed: 0                                               Name 5* ratings  \
# 0            0                Apple iPhone 15 Plus (Blue, 128 GB)      2,148
# 1            1        Apple iPhone 15 Pro (Blue Titanium, 128 GB)        399
# 2            2    Apple iPhone 15 Pro Max (Blue Titanium, 256 GB)        292
# 3            3     vivo X100 (Stargaze Blue, 256 GB)  (12 GB RAM)        293
# 4            4    OPPO Reno11 5G (Wave Green, 128 GB)  (8 GB RAM)      1,460
# 5            5  OPPO Reno11 Pro 5G (Pearl White, 256 GB)  (12 ...        655
# 6            6  Infinix SMART 8 (Rainbow Blue, 64 GB)  (4 GB RAM)      1,317
# 7            7          Google Pixel 7a (Sea, 128 GB)  (8 GB RAM)      9,211
# 8            8  Motorola Edge 40 (Eclipse Black, 256 GB)  (8 G...     44,719
# 9            9            POCO C55 (Cool Blue, 64 GB)  (4 GB RAM)        NaN
# 10          10  SAMSUNG Galaxy S24 5G (Amber Yellow, 256 GB)  ...        160
# ...

# %%
import pandas as pd

# %%
df.groupby('Battery').Battery. count()
# Out:
# Battery
# 4000 mAh Battery     1
# 4300 mAh Battery     1
# 4400 mAh Battery     1
# 4575 mAh Battery     1
# 4600 mAh Battery     2
# 5000 mAh Battery    20
# 5050 mAh Battery     1
# 5160 mAh Battery     1
# Name: Battery, dtype: int64

# %%
df['5* ratings'].dtype
# Out:
# dtype('O')
